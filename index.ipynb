# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
# Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
# Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# open the first events page and save as a soup
html_page = requests.get('https://www.residentadvisor.net/events/us/newyork/week/2020-03-03')
if html_page.status_code == 200:
    soup = BeautifulSoup(html_page.content, 'html.parser')
else:
    print('something went wrong.  the status code is: ', html_page.status_code)

# %%
event_items = soup.findAll(attrs={'class': 'event-item'})
print(len(event_items))
print(event_items[0])
# Out:
# 75
# <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-03-03T00:00" itemprop="startDate">2020-03-03T00:00</time></span><a href="/events/1392346"><img height="76" src="/images/events/flyer/2020/3/us-0303-1392346-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1392346" itemprop="url" title="Event details of Hart &amp; Soul 10 with The Duchess">Hart &amp; Soul 10 with The Duchess</a> <span>at <a href="/club.aspx?id=71292">Bossa Nova Civic Club</a></span></h1><div class="grey event-lineup">The Duchess, Son of Lee, kyle.wav</div><p class="attending"><span>4</span> Attending</p></div></article>

# %%
# event_date
event_items[0].find('time').text[:10]
# Out:
# '2020-02-25'

# %%
# event_name
event_items[0].find(attrs={'class': 'event-title'}).find('a').text
# Out:
# 'Aggressive Skool Nite'

# %%
# venue
event_items[0].find(attrs={'class': 'event-title'}).find('span').find('a').text
# Out:
# 'Jupiter Disco'

# %%
# number_of_attendees
int(event_items[0].find(attrs={'class': 'attending'}).find('span').text)
# Out:
# 5

# %%
event_items[104]
# Out:
# <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-03-02T00:00" itemprop="startDate">2020-03-02T00:00</time></span><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1387620" itemprop="url" title="Event details of The Office presents: Shhh Music By: Deborah Sattler">The Office presents: Shhh Music By: Deborah Sattler</a> <span>at <span class="grey" style="display:inline;">TBA - Brooklyn</span></span></h1></div></article>

# %%
event_items[30].find(attrs={'class': 'event-title'}).find('span').find('a').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-782495aa1f47> in <module>
# ----> 1 event_items[30].find(attrs={'class': 'event-title'}).find('span').find('a').text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
event_url = event_items[0].find(attrs={'class': 'event-title'}).find('a')['href']
event_url
# Out:
# '/events/1382985'

# %%
event_url = event_items[8].find(attrs={'class': 'event-title'}).find('a')['href']
event_page = requests.get(f'https://www.residentadvisor.net{event_url}')
if event_page.status_code == 200:
    event_soup = BeautifulSoup(event_page.content, 'html.parser')
    print(int(event_soup.find(id='MembersFavouriteCount').text))
else:
    print(f'something went wrong with {event_url}.  the status code is: {event_page.status_code}')
# Out:
# 4

# %%
def scrape_events(events_page_url):
    
    # debugging flag
    DEBUG = False
    
    # initialize lists for the scraped data
    event_dates = []
    event_names = []
    venues = []
    attendees = []
    
    # load the html page into a soup
    html_page = requests.get(events_page_url)
    
    # check if the page was sucessfully loaded
    if html_page.status_code == 200:
        soup = BeautifulSoup(html_page.content, 'html.parser')
    else:
        print('something went wrong.  the status code is: ', html_page.status_code)
        return None
    
    # create a list of all the events
    event_items = soup.findAll(attrs={'class': 'event-item'})
    
    # store the number of events on the page in a var
    num_events = len(event_items)
    
    # loop through the events, loading them into the lists
    for i in range(0,num_events):
        print('event #', i) if DEBUG else None
        
        event_date = event_items[i].find('time').text[:10]
        print(event_date) if DEBUG else None
        event_dates.append(event_date)
        
        event_name = event_items[i].find(attrs={'class': 'event-title'}).find('a').text
        print(event_name) if DEBUG else None
        event_names.append(event_name)
        
        venue_element = event_items[i].find(attrs={'class': 'event-title'}).find('span')
        if venue_element.find('a'): # event location has a link
            venue = venue_element.find('a').text
        elif venue_element.find('span'): # event location doesn't have a link
            venue = venue_element.find('span').text
        print(venue) if DEBUG else None
        venues.append(venue)
        
        attendee_element = event_items[i].find(attrs={'class': 'attending'})
        if attendee_element: # there is a number of attendees listed on this page
            num_attendees = int(attendee_element.find('span').text)
        else: # there are no attendees listed on this page
            # open the event details page
            event_url = event_items[i].find(attrs={'class': 'event-title'}).find('a')['href']
            event_page = requests.get(f'https://www.residentadvisor.net{event_url}')
            if event_page.status_code == 200:
                event_soup = BeautifulSoup(event_page.content, 'html.parser')
                num_attendees = int(event_soup.find(id='MembersFavouriteCount').text)
            else:
                print(f'something went wrong with {event_url}.  the status code is: {event_page.status_code}')
        print(num_attendees) if DEBUG else None
        attendees.append(num_attendees)

    df = pd.DataFrame([event_names, venues, event_dates, attendees]).transpose()
    
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return df

# %%
df = scrape_events('https://www.residentadvisor.net/events')
print('total events: ',len(df))
df.head()
# Out:
# event # 0
# 2020-02-25
# Aggressive Skool Nite
# Jupiter Disco
# 5
# event # 1
# 2020-02-25
# Cheers Bklyn 32
# TBA Brooklyn
# 5
# event # 2
# 2020-02-25
# Feel Real presents Purified
# Rumpus Room
# 1
# event # 3
# 2020-02-25
# Cool Runnings with MKL
# Wei's
# 1
# event # 4
# 2020-02-26
# Pure Immanence Xliii
# Bossa Nova Civic Club
# 15
# event # 5
# 2020-02-26
# Wednesday Films: Buena Vista Social Club
# Nowadays
# 13
# event # 6
# 2020-02-26
# Exit 32 Recordings Showcase with Alex Fogo, Federico Moore
# TBA Brooklyn
# 7
# event # 7
# 2020-02-26
# Funk You with DJ Bruce
# House Of Yes
# 4
# event # 8
# 2020-02-26
# Rare Frequency Transmissions
# Jupiter Disco
# 4
# event # 9
# 2020-02-26
# Strange Edition Launch with GAIKA, Azekel, Russell E.L. Butler and Gloria
# Strange Edition
# 4
# event # 10
# 2020-02-26
# Open Decks Session 101
# Eris
# 3
# event # 11
# 2020-02-26
# Happy Hour
# H0L0
# 0
# event # 12
# 2020-02-26
# Shots
# Blank Forms
# 0
# event # 13
# 2020-02-27
# Deep Root Sessions At Public Arts with Leftwing:Kody
# Public Arts
# 9
# event # 14
# 2020-02-27
# Modular Synthesis Workshop: Apocalipsis U
# Nowadays
# 23
# event # 15
# 2020-02-27
# TYGAPAW
# public records
# 19
# event # 16
# 2020-02-27
# Synergy X {DatKat, Rabia Khan, Panooc}
# Jupiter Disco
# 18
# event # 17
# 2020-02-27
# Champgne Bbblrz: Star Eyes x Nasty Nigel x Bamboozle x Jubilee x Izabella
# Black Flamingo
# 6
# event # 18
# 2020-02-27
# Seasoning: Paurro / Rasec / Clay Matthewman
# Mood Ring
# 3
# event # 19
# 2020-02-27
# De La'funk & Friends at TBA
# TBA Brooklyn
# 3
# event # 20
# 2020-02-27
# Midtown House at High Bar: Olive T, Azuro, Kithy, Pedro Cañas
# Highbar NYC
# 2
# event # 21
# 2020-02-27
# Sazón Department X Le Bain
# Le Bain
# 2
# event # 22
# 2020-02-27
# Perk Anniversary with Trinidadian Deep, Rimarkable, DJ Tara & AQ
# Good Room
# 2
# event # 23
# 2020-02-27
# yes&yay Pres: The Den - Marca, Yancy Wolfgang, Niichavo
# Macao Trading Company
# 1
# event # 24
# 2020-02-27
# The Server Trash Circus
# H0L0
# 1
# event # 25
# 2020-02-27
# Shots
# Blank Forms
# 0
# event # 26
# 2020-02-27
# Telefon Tel Aviv
# Buffalo/Rochester
# 0
# event # 27
# 2020-02-27
# Uptown Nikko b2b Johnsville in Paradise
# Paradise Club
# 0
# event # 28
# 2020-02-28
# Pangaea / Galcher Lustwerk / Lauren Flax
# BASEMENT
# 123
# event # 29
# 2020-02-28
# Friday: DJ Python and Valesuchi
# Nowadays
# 61
# event # 30
# 2020-02-28
# The Selectors present Onur Ozer, Taimur, Steven Letigre
# TBA - New York
# 43
# event # 31
# 2020-02-28
# ZeroSpace presents Matthias Meyer, Lauren Ritter, Christian Voldstad
# Zerospace
# 39
# event # 32
# 2020-02-28
# Signal > Noise presents: Derek Plaslaiko
# Jackrabbit Club
# 35
# event # 33
# 2020-02-28
# Kyle Hall, Joey Anderson & Morgan
# Elsewhere
# 21
# event # 34
# 2020-02-28
# Klandest: Sasha Carassi / Miss Jennifer
# The Paper Box
# 20
# event # 35
# 2020-02-28
# Loud Minority with Mike Huckaby, Shawn Dub, Monchan Plus MNMLKTCHN with Analog Soul
# Good Room
# 19
# event # 36
# 2020-02-28
# Super Flu, Hyenah, Rimarkable
# House Of Yes
# 16
# event # 37
# 2020-02-28
# Spa of Sensorium: Gorje Hewek & Izhevski, The Scumfrog
# TBA - New York
# 9
# event # 38
# 2020-02-28
# Apocalipsis: “Traviesa” Release Party with Shell X (Live) and More
# Elsewhere
# 5
# event # 39
# 2020-02-28
# Agree II Disagree with Steve Tek, Mr. O'neil, Johan, Guevara
# TBA Brooklyn
# 3
# event # 40
# 2020-02-28
# Danny Kolk In The Water Tower
# The Water Tower Bar
# 2
# event # 41
# 2020-02-28
# Underground System (Live), Yasser Tejeda (Live), Nickodemus (Live), Eli Soul Clap (DJ)
# The Sultan Room
# 1
# event # 42
# 2020-02-28
# Despacito with AceMo, Dreemseed, Tarrou & Amelia Holt
# Mood Ring
# 24
# event # 43
# 2020-02-28
# Takaya Nagase & Yuji Kawasaki (Joy, NYC)
# Le Bain
# 11
# event # 44
# 2020-02-28
# Soulwax
# Brooklyn Steel
# 9
# event # 45
# 2020-02-28
# Bushwacka
# public records
# 9
# event # 46
# 2020-02-28
# Perk with Rose Kourts x Sunny Cheeba x Jadalareign.
# Black Flamingo
# 3
# event # 47
# 2020-02-28
# Penthouse
# Rebecca's
# 2
# event # 48
# 2020-02-28
# Sound Gymnastics / Bring Your Own Vinly
# Gertie
# 2
# event # 49
# 2020-02-28
# Earthen Sea / Skeleton Zoo / Alphabets
# TBA - New York
# 2
# event # 50
# 2020-02-28
# Maccarson + Ahmee
# Elsewhere
# 1
# event # 51
# 2020-02-28
# An Evening Of Quadraphonic Sounds
# Flux Factory
# 1
# event # 52
# 2020-02-28
# Easy in Paradise: Pabels / Wilki / Jordan James
# Paradise Club
# 1
# event # 53
# 2020-02-28
# The Next Level Party Finale
# Frank's Lounge
# 1
# event # 54
# 2020-02-29
# Cityfox Live Festival: Paul Kalkbrenner, Schwarzmann (Frank Wiedemann & Henrik Schwarz) & More
# Avant Gardner
# 1475
# event # 55
# 2020-02-29
# The Bunker and Interdimensional Transmissions present No Way Back NYC
# Market Hotel
# 165
# event # 56
# 2020-02-29
# Altær: Henning Baer / VSK / Volvox / Auspex
# BASEMENT
# 141
# event # 57
# 2020-02-29
# Honey Soundsystem Good Room Takeover
# Good Room
# 65
# event # 58
# 2020-02-29
# Cinthie, Occupy the Disco
# Elsewhere
# 36
# event # 59
# 2020-02-29
# Boris
# 3 Dollar Bill
# 31
# event # 60
# 2020-02-29
# Saturday: FNV (JT Almon & Michael Magnan) and Vicki Powell
# Nowadays
# 24
# event # 61
# 2020-02-29
# CCL & ADAB
# public records
# 16
# event # 62
# 2020-02-29
# Marshall Jefferson and Razor 'N' Tape
# House Of Yes
# 14
# event # 63
# 2020-02-29
# Viceroy, Instant Classic, Wilki
# Elsewhere
# 12
# event # 64
# 2020-02-29
# Soup x Fam - Joe Pompeo's Bday
# TBA Brooklyn
# 5
# event # 65
# 2020-02-29
# Nomi Ruiz 'Jet Black' Premiere (Live) , MS Boogie, Dylan The Gypsy (DJ SET)
# The Sultan Room
# 1
# event # 66
# 2020-02-29
# Xoxa with Panooc, Rabia Khan, Kandylion, Honey B
# Elsewhere
# 21
# event # 67
# 2020-02-29
# Boo Williams (Chicago)
# Le Bain
# 12
# event # 68
# 2020-02-29
# Sole Rehab 051 - The Carry Nation
# Buffalo/Rochester
# 6
# event # 69
# 2020-02-29
# Good-Natured Sound: Quantum Leap
# Evil Olive Pizza Bar
# 5
# event # 70
# 2020-02-29
# Ryan Crosson b2b Shaun Reeves / Gian-Paul in Paradise
# Paradise Club
# 5
# event # 71
# 2020-02-29
# Katie Gately NYC Record Release Show
# Knockdown Center
# 3
# event # 72
# 2020-02-29
# Darker Than Wax presents Nina Sol with Marco Weibel & Mawkus
# Jupiter Disco
# 3
# event # 73
# 2020-02-29
# Elephante
# Webster Hall
# 2
# event # 74
# 2020-02-29
# BDA with John FM and Toribio
# Black Flamingo
# 2
# event # 75
# 2020-02-29
# New York Modular Society
# Wonderville
# 2
# event # 76
# 2020-02-29
# Intercalation
# Mood Ring
# 2
# event # 77
# 2020-02-29
# Xmpz / Donis / Morenxxx / Salenta
# Bossa Nova Civic Club
# 2
# event # 78
# 2020-02-29
# Trancespotting
# Rebecca's
# 2
# event # 79
# 2020-02-29
# Jichael Mackson (Live)
# TBA - Brooklyn
# 2
# event # 80
# 2020-02-29
# FSQ NYC - Leap Year 2020
# Ponyboy
# 1
# event # 81
# 2020-02-29
# Holland Andrews: Onè
# Issue Project Room
# 1
# event # 82
# 2020-02-29
# The Office presents: RAW Music By: Gio Vanni
# TBA - New York
# 1
# event # 83
# 2020-02-29
# Seeing Sounds with Marcus Logan
# public records
# 1
# event # 84
# 2020-02-29
# 7587 presents: Techno Happy Hour W/ Frtitz Ta Ramsey Neville Misael
# Bossa Nova Civic Club
# 1
# event # 85
# 2020-02-29
# Brooklyn Haze: A Deep House Experience
# Artel BK
# 1
# event # 86
# 2020-02-29
# Lavo Saturdays with Kingsman
# Lavo New York
# 1
# event # 87
# 2020-02-29
# The Feb. 29 Aaron Benefit
# Nublu Classic
# 0
# event # 88
# 2020-02-29
# 5th of Nov.
# The Graham
# 0
# event # 89
# 2020-03-01
# 7th Heaven with Joey Llanos and Douglas Sherman
# Good Room
# 9
# event # 90
# 2020-03-01
# Sunday: Blazer Sound System All Day
# Nowadays
# 6
# event # 91
# 2020-03-01
# Taj Lounge NYC Hip Hop vs. Reggae™ Sunday Funday Brunch Party
# Taj Lounge
# 1
# event # 92
# 2020-03-01
# Elixirs Of Sound with rrao, Jessica Caplan
# Halcyon The Shop
# 1
# event # 93
# 2020-03-01
# Birdcage with Hex Hector & Ahmee Lin
# Le Bain
# 3
# event # 94
# 2020-03-01
# Paradisco by Occupy The Disco
# Le Bain
# 3
# event # 95
# 2020-03-01
# Sage Caswell/Dearly Departure/Alphabets/CD Player/DJ Lostcat
# H0L0
# 2
# event # 96
# 2020-03-01
# Acacia presents: Sayed & León
# Jupiter Disco
# 1
# event # 97
# 2020-03-01
# Sunday Soiree: Black/Tuesday, Alexander Gentil
# TBA Brooklyn
# 1
# event # 98
# 2020-03-01
# Dance Yourself Clean (1st Fridays) Brooklyn
# Baby's All Right
# 1
# event # 99
# 2020-03-01
# Theflowproject: Sundayshindig
# Silver Factory
# 1
# event # 100
# 2020-03-02
# Elixirs Of Sound with rrao, Jessica Caplan
# Halcyon The Shop
# 1
# event # 101
# 2020-03-02
# Paradisco by Occupy The Disco
# Le Bain
# 3
# event # 102
# 2020-03-02
# Tech0l0
# H0L0
# 2
# event # 103
# 2020-03-02
# Fermented Frequency: Katie Rex, DJ Wawa, Posi-Track
# Bossa Nova Civic Club
# 2
# event # 104
# 2020-03-02
# The Office presents: Shhh Music By: Deborah Sattler
# TBA - Brooklyn
# 1
# 105
#                     Event_Name                  Venue  Event_Date  \
# 0        Aggressive Skool Nite          Jupiter Disco  2020-02-25
# 1              Cheers Bklyn 32           TBA Brooklyn  2020-02-25
# 2  Feel Real presents Purified            Rumpus Room  2020-02-25
# 3       Cool Runnings with MKL                  Wei's  2020-02-25
# 4         Pure Immanence Xliii  Bossa Nova Civic Club  2020-02-26
#
#   Number_of_Attendees
# 0                   5
# 1                   5
# 2                   1
# 3                   1
# 4                  15

# %%
sorted_df = df.sort_values(by=['Number_of_Attendees', 'Event_Date'], ascending=False)
sorted_df
# Out:
#                                            Event_Name              Venue  \
# 54  Cityfox Live Festival: Paul Kalkbrenner, Schwa...      Avant Gardner
# 55  The Bunker and Interdimensional Transmissions ...       Market Hotel
# 56        Altær: Henning Baer / VSK / Volvox / Auspex           BASEMENT
# 28           Pangaea / Galcher Lustwerk / Lauren Flax           BASEMENT
# 57               Honey Soundsystem Good Room Takeover          Good Room
# ..                                                ...                ...
# 25                                              Shots        Blank Forms
# 26                                   Telefon Tel Aviv  Buffalo/Rochester
# 27            Uptown Nikko b2b Johnsville in Paradise      Paradise Club
# 11                                         Happy Hour               H0L0
# 12                                              Shots        Blank Forms
#
#     Event_Date Number_of_Attendees
# 54  2020-02-29                1475
# 55  2020-02-29                 165
# 56  2020-02-29                 141
# 28  2020-02-28                 123
# 57  2020-02-29                  65
# ..         ...                 ...
# 25  2020-02-27                   0
# 26  2020-02-27                   0
# 27  2020-02-27                   0
# 11  2020-02-26                   0
# 12  2020-02-26                   0
#
# [105 rows x 4 columns]

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
def next_page(url):
    # load the html page into a soup
    html_page = requests.get(url)
    
    # check if the page was sucessfully loaded
    if html_page.status_code == 200:
        soup = BeautifulSoup(html_page.content, 'html.parser')
    else:
        print(f'something went wrong with {url}.  the status code is: {html_page.status_code}')
        return None
    
    # get the url anchor element
    url_anchor =  soup.find(id='liNext').find('a')
    
    # if url_anchor exists and has an href attribute
    if url_anchor and url_anchor.has_attr('href'):
        next_page_url = 'https://www.residentadvisor.net' + url_anchor['href']
    else: # you're at the last page and there is no next
        next_page_url = None
    
    return next_page_url

# %%
next_page('https://www.residentadvisor.net/events')
# Out:
# 'https://www.residentadvisor.net/events/us/newyork/week/2020-03-03'

# %%
next_page('https://www.residentadvisor.net/events/us/newyork/week/2020-03-03')
# Out:
# 'https://www.residentadvisor.net/events/us/newyork/week/2020-03-10'

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
# Initialize the number of scraped events
scraped_events = 0
# set a max number of events
MAX_EVENTS = 1000
# initialize page url
url = 'https://www.residentadvisor.net/events'
# initialize an empty Events data frame
events_df = pd.DataFrame()
# set debug flag
DEBUG_HERE = True

while (scraped_events < MAX_EVENTS) and (url != None):
    
    print('current page ', url) if DEBUG_HERE else None
    
    # scrape the events from the current page
    df = scrape_events(url)
    
    # if this if the first scrape
    if scraped_events == 0:
        events_df = df
    else:
        # concatenate the newly scraped events to the events data frame
        events_df = pd.concat([events_df, df])
        
    # update the number of scraped events
    scraped_events = len(events_df)
    
    print('scraped events so far: ', scraped_events) if DEBUG_HERE else None
    
    # get the url of the next page
    url = next_page(url)
# Out:
# current page  https://www.residentadvisor.net/events
# scraped events so far:  105
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-03-03
# scraped events so far:  180
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-03-10
# scraped events so far:  242
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-03-17
# scraped events so far:  293
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-03-24
# scraped events so far:  333
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-03-31
# scraped events so far:  359
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-04-07
# scraped events so far:  384
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-04-14
# scraped events so far:  405
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-04-21
# scraped events so far:  419
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-04-28
# scraped events so far:  435
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-05-05
# scraped events so far:  449
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-05-12
# scraped events so far:  459
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-05-19
# scraped events so far:  466
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-05-26
# scraped events so far:  469
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-06-02
# scraped events so far:  474
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-06-09
# scraped events so far:  481
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-06-16
# scraped events so far:  486
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-06-23
# scraped events so far:  487
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-06-30
# scraped events so far:  487
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-07-07
# scraped events so far:  488
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-07-14
# scraped events so far:  493
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-07-21
# scraped events so far:  493
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-07-28
# scraped events so far:  494
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-08-04
# scraped events so far:  494
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-08-11
# scraped events so far:  495
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-08-18
# scraped events so far:  495
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-08-25
# scraped events so far:  495
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-09-01
# scraped events so far:  495
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-09-08
# scraped events so far:  495
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-09-15
# scraped events so far:  496
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-09-22
# scraped events so far:  497
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-09-29
# scraped events so far:  497
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-10-06
# scraped events so far:  497
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-10-13
# scraped events so far:  497
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-10-20
# scraped events so far:  497
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-10-27
# scraped events so far:  497
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-11-03
# scraped events so far:  497
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-11-10
# scraped events so far:  497
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-11-17
# scraped events so far:  497
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-11-24
# scraped events so far:  497
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-12-01
# scraped events so far:  498
# current page  https://www.residentadvisor.net/events/us/newyork/week/2020-12-08
# scraped events so far:  498

# %%
sorted_df = events_df.iloc[:MAX_EVENTS].sort_values(by=['Number_of_Attendees', 'Event_Date'], ascending=False)
sorted_df
# Out:
#                                            Event_Name              Venue  \
# 54  Cityfox Live Festival: Paul Kalkbrenner, Schwa...      Avant Gardner
# 7   Brooklyn Mirage Opening Weekend 2020: Cityfox ...    Brooklyn Mirage
# 25                Carl Cox Invites: Brooklyn Takeover      Avant Gardner
# 17      Zero presents... The Masquerade 2020: Clarity     TBA - Brooklyn
# 28                Amelie Lens / Farrago / Rachel Noon   Knockdown Center
# ..                                                ...                ...
# 25                                              Shots        Blank Forms
# 26                                   Telefon Tel Aviv  Buffalo/Rochester
# 27            Uptown Nikko b2b Johnsville in Paradise      Paradise Club
# 11                                         Happy Hour               H0L0
# 12                                              Shots        Blank Forms
#
#     Event_Date Number_of_Attendees
# 54  2020-02-29                1481
# 7   2020-05-09                 831
# 25  2020-03-28                 585
# 17  2020-04-04                 340
# 28  2020-03-21                 340
# ..         ...                 ...
# 25  2020-02-27                   0
# 26  2020-02-27                   0
# 27  2020-02-27                   0
# 11  2020-02-26                   0
# 12  2020-02-26                   0
#
# [498 rows x 4 columns]

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully developed a pipeline to scrape a website for concert event information!
